# %% [markdown]
# # --------------------------Python OOPs Questions--------------------------

# %% [markdown]
# ## 1. What is Object-Oriented Programming ()?

# %% [markdown]
# ### Ans: Object-oriented programming is a programming paradigm that provides a means of structuring programs so that properties and behaviors are bundled into individual objects

# %% [markdown]
# ## 2.What is a class in OOP?

# %% [markdown]
# ### Ans: Class is a blueprint or template for creating objects. It is a user-defined data type that defines the common properties (attributes or variables) and behaviors (methods or functions) that all objects of that type will call.

# %% [markdown]
# ## 3. What is an object in OOP?

# %% [markdown]
# ### ANs: Object is a real instance of a class. It represents a specific thing that has data and behavior. It stores data and can perform actions on methods.

# %% [markdown]
# ## 4. What is the difference between abstraction and encapsulation?

# %% [markdown]
# ### Ans: Abstraction is hiding unnecessary details and show only the essential features in a class. Encapsulation bundles data and methods together and restrict direct access.

# %% [markdown]
# ## 5. What are dunder methods in Python?

# %% [markdown]
# ### Ans: Dunder method is a special methods defined with a double underscore before and after the name of a function. It is also called magic methods in python. Dunder methods are not usually called directly — Python calls them behind the scenes when appropriate. Ex of dunder methods          \__init\__   \__str\__   \__add\__   \__len\__

# %% [markdown]
# ## 6. Explain the concept of inheritance in OOP

# %% [markdown]
# ### Ans: Inheritance is a main concept in Object-Oriented Programming (OOP) that lets you create new classes based on existing ones. It enables a child/derived class to reuse attributes and methods from a parent/base/super class, which promotes code reuse, organization, and hierarchical design.

# %% [markdown]
# ## 7. What is polymorphism in OOP?

# %% [markdown]
# ### Ans: Polymorphism means (poly=many, morphism=forms)  that the same function, method, or operator can work with different types of objects, and each object responds in its own way. Ex function overloading, function overriding etc.

# %% [markdown]
# ## 8. How is encapsulation achieved in Python?

# %% [markdown]
# ### Ans. Encapsulation in Python is achieved by bundling data (variables) and methods into a single unit (class) and controlling access to the data using access conventions and properties.

# %% [markdown]
# ## 9. What is a constructor in Python?

# %% [markdown]
# ### Ans. A constructor in Python is a special method that is automatically called when an object of a class is created. <br> It is used to initialize the object’s data members. The constructor is named as \__init\__() method.

# %% [markdown]
# ## 10. What are class and static methods in Python?

# %% [markdown]
# ### Ans. A class method works with the class itself, not with individual objects. It is defined using @classmethod can takes cls as the first parameter, can access and modify class variables. It can be called using class name or object.

# %% [markdown]
# ## 11. What is method overloading in Python?

# %% [markdown]
# ### Ans. Method overloading means defining multiple methods with the same name but different parameters. <br>Python does not support method overloading . If you define multiple methods with the same name in a class, the last one overrides the previous ones.

# %% [markdown]
# ## 12.What is method overriding in OOP?

# %% [markdown]
# ### Ans. Method overriding in OOP is a concept where a subclass provides its own implementation of a method that is already defined in its parent (super) class.

# %% [markdown]
# ## 13. What is a property decorator in Python?

# %% [markdown]
# ### Ans. The @property decorator in Python is used to define methods that can be accessed like attributes, while still allowing control, validation, and encapsulation. Here we can call a method like  a variable.

# %% [markdown]
# ## 14. Why is polymorphism important in OOP

# %% [markdown]
# ### Ans. Polymorphism is important in oop because it allows objects of different classes to be treated in a uniform way, while still behaving according to their specific type

# %% [markdown]
# ## 15 What is an abstract class in Python?

# %% [markdown]
# ### Ans.  An abstract class in Python is a class that cannot be instantiated and is meant to be inherited by other classes. It defines abstract methods that must be implemented by its subclasses. Abstract classes are used to enforce a common interface and provide a base structure for derived classes.

# %% [markdown]
# ## 16. What are the advantages of OOP?

# %% [markdown]
# ### Ans. OOP offers several advantages that make software modular, reusable, scalable, and easy to maintain. Some advantages are….<br> Modularity, Encapsulation (Data Hiding), Polymorphism, Abstraction, Maintainability, Improved Code Organization etc

# %% [markdown]
# ## 17. What is the difference between a class variable and an instance variable?

# %% [markdown]
# ### Ans. Class variable : A class variable is shared by all objects of a class. It is declared inside the class, outside any method. Can accessed by class name or object.<br>Instance variable: An instance variable is a variable that unique to each object. It is declared inside the constructor using self. Can be accessed by object only

# %% [markdown]
# ## 18. What is multiple inheritance in Python?

# %% [markdown]
# ### Ans. Multiple inheritance in Python is a feature where a child class inherits from more than one parent class.<br>This allows the child class to reuse attributes and methods from multiple base classes.

# %% [markdown]
# ## 19. Explain the purpose of \__str\__ and \__repr\__ methods in Python

# %% [markdown]
# ### Ans. Both __str__ and __repr__ are special (dunder) methods used to define string representations of objects, but they serve different purposes. \__str\__  is user friendly representation and  \__repr\__  is developer-Friendly representation

# %% [markdown]
# ## 20. What is the significance of the ‘super()’ function in Python?

# %% [markdown]
# ### Ans. The super() function is used to call methods of a parent (super) class from a child (sub) class.<br>It is most commonly used in inheritance to extend or reuse parent class functionality.

# %% [markdown]
# ## 21. What is the significance of the __del__ method in Python?

# %% [markdown]
# ### Ans. The \__del\__ method is a special (destructor) method in Python that is called when an object is about to be destroyed (garbage collected) <br>Its main purpose is to perform cleanup operations before the object is removed from memory.

# %% [markdown]
# ## 22. What is the difference between @staticmethod and @classmethod in Python?

# %% [markdown]
# ### Ans. Both @staticmethod and @classmethod define methods inside a class, but they differ in how they access class data and how they are used.<br>@staticmethod : is  defined using @staticmethod, takes no self or cls, cannot access instance or class variables directly, behaves like a regular function<br>@classmethod : •  is defined using @classmethod, takes cls as the first parameter, can access and modify class variables, works with class-level data, can be called using the class or an object.

# %% [markdown]
# ## 23. How does polymorphism work in Python with inheritance?

# %% [markdown]
# ### Ans. 23.	In Python, polymorphism with inheritance works through method overriding and dynamic (runtime) binding.<br>A child class can provide its own implementation of a method defined in a parent class, and Python decides at runtime which method to execute based on the object’s type.

# %% [markdown]
# ## 24. What is method chaining in Python OOP?

# %% [markdown]
# ### Ans. Method chaining is a technique where multiple methods are called on the same object in a single statement, with each method returning the object itself (self) so that the next method can be called.

# %% [markdown]
# ## 25. What is the purpose of the \__call\__ method in Python?

# %% [markdown]
# ### Ans. The \__call\__ method allows an object of a class to be called like a function.<br>When an instance is “called” using parentheses (), Python internally invokes its \__call\__ method.

# %% [markdown]
# # ==============Practical Questions================

# %% [markdown]
# ## 1.  Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".

# %%
class Animal:
    def speak(self):
        print("The animal makes a sound.")

class Dog(Animal):
    def speak(self):
        print("Bark!")

# %%
a = Animal()
a.speak()
d = Dog()
d.speak()
# Out:
# The animal makes a sound.
# Bark!

# %% [markdown]
# ## 2.  Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.

# %%
from abc import ABC, abstractmethod
import math

# Abstract base class
class Shape(ABC):

    @abstractmethod
    def area(self):
        pass

# Derived class: Circle
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

# Derived class: Rectangle
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# %%
c = Circle(10)
r = Rectangle(2, 3)

print("Area of Circle:", c.area())
print("Area of Rectangle:", r.area())
# Out:
# Area of Circle: 314.1592653589793
# Area of Rectangle: 6

# %% [markdown]
# ## 3.  Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute

# %%
# Base class
class Vehicle:
    def __init__(self, vehicle_type):
        self.type = vehicle_type

    def show_type(self):
        print("Vehicle type:", self.type)

# Derived class (Level 1)
class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)
        self.brand = brand

    def show_brand(self):
        print("Car brand:", self.brand)

# Derived class (Level 2)
class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery_capacity):
        super().__init__(vehicle_type, brand)
        self.battery = battery_capacity

    def show_battery(self):
        print("Battery capacity:", self.battery, "kWh")

# %%
# Example usage
ec = ElectricCar("Four-wheeler", "Suzuki", 100)

ec.show_type()
ec.show_brand()
ec.show_battery()
# Out:
# Vehicle type: Four-wheeler
# Car brand: Suzuki
# Battery capacity: 100 kWh

# %% [markdown]
# ## 4.  Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.

# %%
class Bird:
    def fly(self):
        print("base class Bird's fly() method invoked")
class Sparrow(Bird):
    def fly(self):
        print("Sparrow overrides the fly() method of base class Bird")
class Penguin(Bird):
    def fly(self):
        print("Penguin overrides the fly() method of base class Bird")

# %%
#test the above program
b =Bird()
b.fly()
s = Sparrow()
s.fly()
p = Penguin()
p.fly()
# Out:
# base class Bird's fly() method invoked
# Sparrow overrides the fly() method of base class Bird
# Penguin overrides the fly() method of base class Bird

# %% [markdown]
# ## 5.  Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance

# %%
class BankAccount:
    def __init__(self, initial_bal=0):
        # Private attribute
        self.__bal = initial_bal

    # Method to deposit money
    def deposit(self, amount):
        if amount > 0:
            self.__bal += amount
            print(f"Deposited: {amount}")
        else:
            print("Invalid deposit amount")

    # Method to withdraw money
    def withdraw(self, amount):
        if amount > 0 and amount <= self.__bal:
            self.__bal -= amount
            print(f"Withdrawn: {amount}")
        else:
            print("Insufficient balance")

    # Method to check balance
    def check_bal(self):
        return self.__bal

# %%
# test the program
acc = BankAccount(1000)

acc.deposit(1000)
acc.withdraw(500)

print("Current Account Balance:", acc.check_bal())
# Out:
# Deposited: 1000
# Withdrawn: 500
# Current Account Balance: 1500

# %% [markdown]
# ## 6.  Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().

# %%
# Base class
class Instrument:
    def play(self):
        print("The instrument's play() invoked")

# Derived class: Guitar
class Guitar(Instrument):
    def play(self):
        print("guitar is playing")

# Derived class: Piano
class Piano(Instrument):
    def play(self):
        print("piano is playing")

# Demonstration of runtime polymorphism
def perform(instrument):
    instrument.play()   # Calls the overridden method at runtime

# %%
# test the program
g = Guitar()
p = Piano()

perform(g)
perform(p)
# Out:
# Strumming the guitar
# Playing the piano

# %% [markdown]
# ## 7.  Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.

# %%
class MathOperations:
    # Class method
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    # Static method
    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# %%
#test the program
sum = MathOperations.add_numbers(25, 15) #static and class methods can call directly by class itself
diff = MathOperations.subtract_numbers(25, 10)

print("Addition:", sum)
print("Subtraction:", diff)
# Out:
# Addition: 40
# Subtraction: 15

# %% [markdown]
# ## 8.  Implement a class Person with a class method to count the total number of persons created.

# %%
class Person:
    # Class variable to keep count of persons
    count_persons = 0
    def __init__(self, name):
        self.name = name
        Person.count_persons += 1

    # Class method to return total count of persons
    @classmethod
    def get_total_persons(cls):
        return cls.count_persons

# %%
# test
p1 = Person("Laxman")
p2 = Person("Lucky")
p3 = Person("Laxmi")
print("Total number of persons created:", Person.get_total_persons())
# Out:
# Total number of persons created: 3

# %% [markdown]
# ## 9.  Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".

# %%
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# %%
# test
f1 = Fraction(5, 4)
f2 = Fraction(5, 2)

print(f1)
print(f2)
# Out:
# 5/4
# 5/2

# %% [markdown]
# ## 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    # Overload + operator
    def __add__(self, other):
        if not isinstance(other, Vector):
            return NotImplemented
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"Vector({self.x}, {self.y})"

# %%
# Example usage
v1 = Vector(5, 10)
v2 = Vector(6, 5)

v3 = v1 + v2

print(v1)
print(v2)
print("Result of addition:", v3)
# Out:
# Vector(5, 10)
# Vector(6, 5)
# Result of addition: Vector(11, 15)

# %% [markdown]
# ## 11.  Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# %%
# test
p1 = Person("Laxman", 32)
p2 = Person("Lucky", 28)

p1.greet()
p2.greet()
# Out:
# Hello, my name is Laxman and I am 32 years old.
# Hello, my name is Lucky and I am 28 years old.

# %% [markdown]
# ## 12.  Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.

# %%
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades  # list of grades

    def average_grade(self):
        if not self.grades:
            return 0
        return sum(self.grades) / len(self.grades)

# %%
#test
s = Student("Laxman", [85, 90, 88])
print(f"{s.name}'s average grade:", s.average_grade())
# Out:
# Laxman's average grade: 87.66666666666667

# %% [markdown]
# ## 13.  Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area

# %%
class Rectangle:
    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# %%
# Example usage
r = Rectangle()
r.set_dimensions(10, 12)

print("Area of rectangle:", r.area())
# Out:
# Area of rectangle: 120

# %% [markdown]
# ## 14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.

# %%
# Base class
class Employee:
    def __init__(self, hours_worked, hourly_rate):
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate


# Derived class
class Manager(Employee):
    def __init__(self, hours_worked, hourly_rate, bonus):
        super().__init__(hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus

# %%
#test
emp = Employee(40, 20)
mgr = Manager(40, 50, 500)

print("Employee Salary:", emp.calculate_salary())
print("Manager Salary:", mgr.calculate_salary())
# Out:
# Employee Salary: 800
# Manager Salary: 2500

# %% [markdown]
# ## 15.  Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

# %%
# test
product = Product("python book", 1000, 2)
print("Total price:", product.total_price())
# Out:
# Total price: 2000

# %% [markdown]
# ## 16.  Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.

# %%
from abc import ABC, abstractmethod

# Abstract base class
class Animal(ABC):

    @abstractmethod
    def sound(self):
        pass

# Derived class: Cow
class Cow(Animal):
    def sound(self):
        return "Moo"

# Derived class: Sheep
class Sheep(Animal):
    def sound(self):
        return "Baa"

# %%
#test
c = Cow()
c.sound()
# Out:
# 'Moo'

# %%
s = Sheep()
s.sound()
# Out:
# 'Baa'

# %% [markdown]
# ## 17.  Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details

# %%
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"Title: {self.title}, Author: {self.author}, Year Published: {self.year_published}"

# %%
# test
book = Book("My Experiment with truth", "M.K. Gandhi", 1925)
print(book.get_book_info())
# Out:
# Title: My Experiment with truth, Author: M.K. Gandhi, Year Published: 1925

# %% [markdown]
# ## 18.  Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.

# %%
# Base class
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

    def show_details(self):
        print(f"Address: {self.address}")
        print(f"Price: {self.price}")

# Derived class
class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

    def show_details(self):
        super().show_details()
        print(f"Number of Rooms: {self.number_of_rooms}")

# %%
obj = Mansion("2B Marathalli Bangalore", 5000000, 20)
obj.show_details()
# Out:
# Address: 2B Marathalli Bangalore
# Price: 5000000
# Number of Rooms: 20
