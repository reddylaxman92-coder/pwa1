# %% [markdown]
# # 1- What are data structures, and why are they important?

# %% [markdown]
# Data structures are ways to store, organize, and manage data efficiently.
# They are important because they help in fast access, modification, and efficient memory usage.

# %% [markdown]
# # 2- Explain the difference between mutable and immutable data types with examplesP

# %% [markdown]
# **Mutable** → can be changed after creation
#
# Examples: list, dict, set
#
# **Immutable** → cannot be changed after creation
#
# Examples: int, float, str, tuple

# %% [markdown]
# # 3- What are the main differences between lists and tuples in Python?

# %% [markdown]
# **List**  is mutable and **Tuple** is immutable.

# %% [markdown]
# # 4-Describe how dictionaries store data?

# %% [markdown]
# **Dictionaries** store data as key–value pairs, where:
#
# Keys are unique and immutable
#
# Values can be of any type.

# %% [markdown]
# # 5-Why might you use a set instead of a list in Python?

# %% [markdown]
# When we  need unique unordered elements in that case we use set instead of list.

# %% [markdown]
# # 6- What is a string in Python, and how is it different from a list?

# %% [markdown]
# A **string** is collection of characters and is immutablwe so it cannot be updated.
#
# A **list** is mutable, so its elements can be updated, added, or removed.

# %% [markdown]
# # 7- How do tuples ensure data integrity in Python?

# %% [markdown]
# **Tuples** are immutable, so their data can not be changed at any cost. This feature ensures data safety.

# %% [markdown]
# # 8- What is a hash table, and how does it relate to dictionaries in Python?

# %% [markdown]
# A hash table stores data using hashing for fast access.
#
# Python dictionaries are implemented using hash tables.

# %% [markdown]
# # 9-Can lists contain different data types?

# %% [markdown]
# Yes list can store mixed of different types of data.

# %% [markdown]
# # 10- Explain why strings are immutable in Python?

# %% [markdown]
# Strings are immutable to:
#
# 1-Improve performance
#
# 2-Ensure memory efficiency
#
# 3-Enable safe reuse of string objects

# %% [markdown]
# # 11- What advantages do dictionaries offer over lists for certain tasks?

# %% [markdown]
# Meaningful data representation
#
# Faster lookup using keys
#
# Efficient for large datasets

# %% [markdown]
# # 12- Describe a scenario where using a tuple would be preferable over a list?

# %% [markdown]
# When you need data safety to use fixed data, that can not be modify in that case you can use tuple.

# %% [markdown]
# # 13- How do sets handle duplicate values in Python?

# %% [markdown]
# Set removes the dubplicate values automatically.

# %% [markdown]
# # 14-P How does the “in” keyword work differently for lists and dictionaries?

# %% [markdown]
# In a **List**, **in**  keyword is used to check existence of values.
#
# In a **Dictionary**, **in** keyword is used to check existence of key.

# %% [markdown]
# # 15- Can you modify the elements of a tuple? Explain why or why not?

# %% [markdown]
# No. We can not modify the tuple. Because tuple is immutable/unchangeble once it's  created.

# %% [markdown]
# # 16-What is a nested dictionary, and give an example of its use case?

# %% [markdown]
# A dictionary inside another dictionary, that is nested dictionary.

# %% [markdown]
# # 17- Describe the time complexity of accessing elements in a dictionary?

# %% [markdown]
# Average time complexity is O(1) (constant time).

# %% [markdown]
# # 18-In what situations are lists preferred over dictionaries?

# %% [markdown]
# Lists are preferred when:
#
# Order matters
#
# Index-based access is needed
#
# Simple sequential data is stored

# %% [markdown]
# # 19-  Why are dictionaries considered unordered, and how does that affect data retrieval?

# %% [markdown]
# Dictionary is unordered because internally it uses hash table to store data in key-value pairs.
#
# Hash values decide where data is stored in memory.
#
# Storage position is not sequential.

# %% [markdown]
# # 20-Explain the difference between a list and a dictionary in terms of data retrieval?

# %% [markdown]
# Using **List**  we can retrieve the data by using index number.
#
# Using **Dictionary** we can retrieve the data by using key name.

# %% [markdown]
# # ---------------Practical Questions-----------

# %% [markdown]
# ###  Write a code to create a string with your name and print it.

# %%
name = "Laxman"
print(name)
# Out:
# Deepak

# %% [markdown]
# ### Write a code to find the length of the string "Hello World".

# %%
strs = "pwskills"
len(strs)
# Out:
# 8

# %% [markdown]
# ### Write a code to slice the first 3 characters from the string "Python Programming".

# %%
s = "Python Programming"
s[:3]
# Out:
# 'Pyt'

# %% [markdown]
# ###  Write a code to convert the string "hello" to uppercaseP

# %%
s="python"
s.upper()
# Out:
# 'PYTHON'

# %% [markdown]
# ###  Write a code to replace the word "apple" with "orange" in the string "I like     apple".

# %%
text="I like learning"
new_text = text.replace("learning","coding")
print(new_text)
# Out:
# I like coding

# %% [markdown]
# ###  Write a code to create a list with numbers 1 to 5 and print it

# %%
lists=[i for i in range(1,6)]
lists
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ###  Write a code to append the number 10 to the list [1, 2, 3, 4].

# %%
lists=[1,2,3,4,5,6]
lists.append(10)
print(lists)
# Out:
# [1, 2, 3, 4, 5, 6, 10]

# %% [markdown]
# ### Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]

# %%
lists=[1,2,3,4]
lists.remove(3)
lists
# Out:
# [1, 2, 4]

# %% [markdown]
# ### Write a code to access the second element in the list ['a', 'b', 'c', 'd']

# %%
lists = ["a","b","c","d"]
lists[1]
# Out:
# 'b'

# %% [markdown]
# ### Write a code to reverse the list [10, 20, 30, 40, 50].

# %%
lists = [10,20,30,40,50]
lists[::-1]
# Out:
# [50, 40, 30, 20, 10]

# %% [markdown]
# ###  Write a code to create a tuple with the elements 100, 200, 300 and print it.

# %%
tup= (100,200,300)
print(tup)
# Out:
# (100, 200, 300)

# %% [markdown]
# ###  Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow').

# %%
tups = ('red', 'green', 'blue', 'yellow')
tups[1:4]
# Out:
# ('green', 'blue', 'yellow')

# %% [markdown]
# ###  Write a code to find the minimum number in the tuple (10, 20, 5, 15)

# %%
numbers = (10, 20, 5,15)

min_num = numbers[0]

for num in numbers:
    if num<min_num:
        min_num=num
print(min_num)
# Out:
# 5

# %% [markdown]
# ### Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').

# %%
tup = ("dog", "cat","rabbit")
index = tup.index("cat")
index
# Out:
# 1

# %% [markdown]
# ### Write a code to create a tuple containing three different fruits and check if "kiwi" is in it.

# %%
fruits = ("apple", "banana", "mango")

if "kiwi" in fruits:
    print("Kiwi is exist in fruits")
else:
    print("Kiwi is not exist in fruits")
# Out:
# Kiwi is not exist in fruits

# %% [markdown]
# ### Write a code to create a set with the elements 'a', 'b', 'c' and print it.

# %%
new_set = {"a","b","c"}
print(new_set)
# Out:
# {'c', 'a', 'b'}

# %% [markdown]
# ### Write a code to clear all elements from the set {1, 2, 3, 4, 5}

# %%
sets={1,2,3,4,5}
sets.clear()
sets
# Out:
# set()

# %% [markdown]
# ### Write a code to remove the element 4 from the set {1, 2, 3, 4}.

# %%
sets_1={1,2,3,4}
sets_1.discard(4)
sets_1
# Out:
# {1, 2, 3}

# %% [markdown]
# ### Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}.

# %%
sets_1={1,2,3}
sets_2={3,4,5}

sets_1 | sets_2
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ### Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}

# %%
set_1={1,2,3}
set_2={2,3,4}

set_1 & set_2
# Out:
# {2, 3}

# %% [markdown]
# ### Write a code to create a dictionary with the keys "name", "age", and "city", and print it.

# %%
dict={"name":"Laxman","age":32,"city":"Bangalore"}
print(dict)
# Out:
# {'name': 'Laxman', 'age': 32, 'city': 'Bangalore'}

# %% [markdown]
# ### Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}.

# %%
dict_2={"name":"John","age":25}
dict_2.update({"country":"USA"})
dict_2
# Out:
# {'name': 'John', 'age': 25, 'country': 'USA'}

# %% [markdown]
# ###  Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}.

# %%
data = {'name': 'Alice', 'age': 30}
print(data["name"])
# Out:
# Alice

# %% [markdown]
# ###  Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}.

# %%
dict={"name":"Bob","age":22,"city":"New York"}
dict.pop("age")
print(dict)
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %% [markdown]
# ### Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}.

# %%
dict_4={'name': 'Alice', 'city': 'Paris'}
print("city" in dict_4)
# Out:
# True

# %% [markdown]
# ### Write a code to create a list, a tuple, and a dictionary, and print them all.

# %%
my_list = [1, 2, 3, 4]


my_tuple = (10, 20, 30)


my_dict = {"name": "Alice", "age": 25}


print(my_list)
print(my_tuple)
print(my_dict)
# Out:
# [1, 2, 3, 4]
# (10, 20, 30)
# {'name': 'Alice', 'age': 25}

# %% [markdown]
# ### Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the result.(replaced)

# %%
import random
numbers = random.sample(range(1,101),5)
print(sorted(numbers))
# Out:
# [6, 40, 51, 77, 79]

# %% [markdown]
# ### Write a code to create a list with strings and print the element at the third index.

# %%
fruitlist = ["apple", "banana", "cherry", "guava", "date"]


print(fruitlist[3])
# Out:
# guava

# %% [markdown]
# ###  Write a code to combine two dictionaries into one and print the result.

# %%
dict1 = {"a": 1, "b": 2}
dict2 = {"c": 3, "d": 4}

combined_dict = {**dict1,**dict2}
print(combined_dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %% [markdown]
# ### Write a code to convert a list of strings into a set.

# %%
lists=["apple", "banana", "cherry", "kiwi", "date"]

print(set(lists))
# Out:
# {'cherry', 'banana', 'date', 'kiwi', 'apple'}
